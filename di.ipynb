# %% [markdown]
# <a href="https://colab.research.google.com/github/Arlo-xrg/Arlo-xrg/blob/main/di.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris, fetch_openml
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
iris = load_iris()
x_iris = iris.data
y_iris = iris.target
print("iris_shape:" , x_iris.shape)
# Out:
# iris_shape: (150, 4)

# %%
scaler = StandardScaler()
x_iris_scaled = scaler.fit_transform(x_iris)

# %%
x_iris_scaled
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
x_train , x_test , y_train , y_test = train_test_split(x_iris_scaled , y_iris , test_size = 0.2)
model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train , y_train)
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test , y_pred)
print("accuracy:" , accuracy)
# Out:
# accuracy: 0.9666666666666667

# %%
pca_iris = PCA()
x_iris_pca = pca_iris.fit_transform(x_iris_scaled)
print("pca_iris_shape:" , x_iris_pca.shape)
print(pca_iris.explained_variance_ratio_)
print(pca_iris.explained_variance_ratio_.sum())
model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train , y_train)
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test , y_pred)
print("accuracy:" , accuracy)
# Out:
# pca_iris_shape: (150, 4)
# [0.72962445 0.22850762 0.03668922 0.00517871]
# 1.0000000000000002
# accuracy: 0.9666666666666667
